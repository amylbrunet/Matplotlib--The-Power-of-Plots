# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1. Upon analyzing the linear regression model of the relationship between the weight of the mice and their average tumor volume, it was evident there was a positive correlation. In addition, the p-value of 0.84 implies that there is also a relatively linear correlation between the two as well. Because of this, I would advise that the mice be kept on a healthy diet and encourge exercise in order to keep their weight down and mitigate the growth of the tumors.
# 2. Of the four drug regimens analyzed, it was evident that Capomulin and Ramicane were the most effective. The average tumor sizes under both of those drug regimens were significantly lower than that of Infubinol and Ceftamin. Based on the data, I would advise to continue researching using both Capomulin and Ramicane to further investigate their effectiveness.
# 3. Overall, the results of this study are very consistent. There were over 100 data points for each drug regimen, which allows us to be fairly confident in the results and see a statistical significance in the data.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "Data/Mouse_metadata.csv"
study_results_path = "Data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_data_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')

# Display the data table for preview
merged_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
merged_data_df['Mouse ID'].value_counts()
# Out:
# g989    13
# x822    10
# a492    10
# n364    10
# x402    10
#         ..
# t573     1
# v199     1
# x226     1
# o848     1
# f932     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_df = merged_data_df.set_index('Mouse ID')
duplicate_df.loc['g989']
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         25
# g989         Propriva  Female          21          26         30
# g989         Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = duplicate_df.drop(['g989'])

# %%
# Checking the number of mice in the clean DataFrame.
new_clean_df = clean_df.reset_index()
new_clean_df['Mouse ID'].value_counts()
# Out:
# x822    10
# e227    10
# q511    10
# k862    10
# i738    10
#         ..
# l872     1
# d133     1
# x226     1
# t573     1
# u153     1
# Name: Mouse ID, Length: 248, dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
tumor_volume_stats = new_clean_df.groupby(['Drug Regimen'])

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
tumor_mean = tumor_volume_stats['Tumor Volume (mm3)'].mean()
tumor_med = tumor_volume_stats['Tumor Volume (mm3)'].median()
tumor_var = tumor_volume_stats['Tumor Volume (mm3)'].var()
tumor_std = tumor_volume_stats['Tumor Volume (mm3)'].std()
tumor_sem = tumor_volume_stats['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary dataframe.
tumor_volume_stats_df = pd.DataFrame({"Mean": tumor_mean,
                                     "Median" : tumor_med,
                                     "Variance" : tumor_var,
                                     "Standard Deviation" : tumor_std,
                                     "SEM" : tumor_sem})
tumor_volume_stats_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line
tumor_stats_2 = new_clean_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])
tumor_stats_2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
timepoint_bar = new_clean_df['Drug Regimen'].value_counts().plot.bar()

#create labels for axes
timepoint_bar.set_xlabel('Drug Regimen')
timepoint_bar.set_ylabel('Number of Timepoints')
timepoint_bar.set_title('Number of Timepoints for Each Drug Regimen')

#show the bar plot
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

# calculate amount of timepoints for y axis
timepoint_count = new_clean_df['Drug Regimen'].value_counts()

# set x axis for each drug regimen using the len
x_axis = np.arange(len(timepoint_count))

# create bar plot with x axis, y axis, and width to match bar plot above
plt.bar(x_axis, timepoint_count, width = 0.5)

#label the x axis tick marks, using index values so names of drug regimen appear
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, timepoint_count.index.values)

# rotate x axis labels for clarity
plt.xticks(rotation=90)

# create labels for axes
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Timepoints')
plt.title('Number of Timepoints for Each Drug Regimen')

# show bar plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# get data on male and female mice for pie plot
pie_data = new_clean_df['Sex'].value_counts()

# plot the pie chart, format percentages, turn the pie chart for readibility, and title
pie_plot = pie_data.plot.pie(autopct="%1.1f%%", startangle=90, title='Sex')

#hide the y label at the side
pie_plot.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# get data on male and female mice for pie plot
pie_data = new_clean_df['Sex'].value_counts()

# create pie chart with data from above, using index values of data as y values
# format percentages and turn 90 degrees
plt.pie(pie_data, labels=pie_data.index.values, autopct="%1.1f%%", startangle=90)
plt.title('Sex')

# show the pie plot
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
greatest_tumor_vol = new_clean_df.groupby(['Mouse ID'])['Timepoint'].max()

# create a data frame of the info above for merging with the original dataframe below
greatest_tumor_vol_df = pd.DataFrame(greatest_tumor_vol)

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# merge on mouse id and timepoint
greatest_tumor_vol_df = pd.merge(new_clean_df, greatest_tumor_vol_df, on=('Mouse ID', 'Timepoint'), how='right')
greatest_tumor_vol_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       a203    Infubinol  Female          20          23         45
# 1       a251    Infubinol  Female          21          25         45
# 2       a262      Placebo  Female          17          29         45
# 3       a275     Ceftamin  Female          20          28         45
# 4       a366     Stelasyn  Female          16          29         30
# ..       ...          ...     ...         ...         ...        ...
# 243     z435     Propriva  Female          12          26         10
# 244     z578     Ramicane    Male          11          16         45
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
capomulin = []
ramicane = []
infubinol = []
ceftamin = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for index, row in greatest_tumor_vol_df.iterrows():
    if row['Drug Regimen'] == 'Capomulin':
        capomulin.append(row['Tumor Volume (mm3)'])
    if row['Drug Regimen'] == 'Ramicane':
        ramicane.append(row['Tumor Volume (mm3)'])
    if row['Drug Regimen'] == 'Infubinol':
        infubinol.append(row['Tumor Volume (mm3)'])
    if row['Drug Regimen'] == 'Ceftamin':
        ceftamin.append(row['Tumor Volume (mm3)'])
        
# create data frame for the info grabbed by for loop to use in later calculations
treatments_df = pd.DataFrame({'Capomulin' : capomulin,
                              'Ramicane' : ramicane,
                              'Infubinol' : infubinol,
                              'Ceftamin' : ceftamin}) 
# show data frame
treatments_df
# Out:
#     Capomulin   Ramicane  Infubinol   Ceftamin
# 0   38.982878  38.407618  67.973419  62.999356
# 1   38.939633  43.047543  65.525743  45.000000
# 2   30.485985  38.810366  57.031862  56.057749
# 3   37.074024  32.978522  66.083066  55.742829
# 4   40.159220  38.342008  72.226731  48.722078
# 5   47.685963  33.397653  36.321346  47.784682
# 6   37.311846  37.311236  60.969711  61.849023
# 7   38.125164  40.659006  62.435404  68.923185
# 8   38.753265  29.128472  60.918767  67.748662
# 9   41.483008  33.562402  67.289621  57.918381
# 10  38.846876  36.374510  66.196912  46.784535
# 11  28.430964  31.560470  62.117279  59.851956
# 12  33.329098  36.134852  47.010364  64.299830
# 13  46.539206  22.050126  60.165180  59.741901
# 14  32.377357  30.564625  55.629428  61.433892
# 15  41.581521  31.095335  45.699331  64.192341
# 16  23.343598  45.220869  54.656549  45.000000
# 17  40.728578  36.561652  55.650681  52.925348
# 18  34.455298  37.225650  46.250112  45.000000
# ...

# %%
# Determine outliers using upper and lower bounds for Capomulin
quartile_cap = treatments_df['Capomulin'].quantile([.25, .5, .75])
lowerq_cap = quartile_cap[0.25]
upperq_cap = quartile_cap[0.75]
iqr_cap = upperq_cap - lowerq_cap
upper_bound_cap = upperq_cap + (1.5*iqr_cap)
lower_bound_cap = lowerq_cap - (1.5*iqr_cap)

# print values and locate outliers for capomulin using calculations above
print(f'Capomulin IQR: {iqr_cap}')
print(f'Capomulin Lower Bound: {lower_bound_cap}')
print(f'Capomulin Upper Bound: {upper_bound_cap}')
print(f'Potential Outliers for Capomulin are values below {lower_bound_cap} or values above {upper_bound_cap}')
# Out:
# Capomulin IQR: 7.781863460000004
# Capomulin Lower Bound: 20.70456164999999
# Capomulin Upper Bound: 51.83201549
# Potential Outliers for Capomulin are values below 20.70456164999999 or values above 51.83201549

# %%
# Determine outliers using upper and lower bounds for Ramicane
quartile_ram = treatments_df['Ramicane'].quantile([.25, .5, .75])
lowerq_ram = quartile_ram[0.25]
upperq_ram = quartile_ram[0.75]
iqr_ram = upperq_ram - lowerq_ram
upper_bound_ram = upperq_ram + (1.5*iqr_ram)
lower_bound_ram = lowerq_ram - (1.5*iqr_ram)

# print values and locate outliers for capomulin using calculations above
print(f'Ramicane IQR: {iqr_ram}')
print(f'Ramicane Lower Bound: {lower_bound_ram}')
print(f'Ramicane Upper Bound: {upper_bound_ram}')
print(f'Potential Outliers for Ramicane are values below {lower_bound_ram} or values above {upper_bound_ram}')
# Out:
# Ramicane IQR: 9.098536719999998
# Ramicane Lower Bound: 17.912664470000003
# Ramicane Upper Bound: 54.30681135
# Potential Outliers for Ramicane are values below 17.912664470000003 or values above 54.30681135

# %%
# Determine outliers using upper and lower bounds for Infubinol
quartile_inf = treatments_df['Infubinol'].quantile([.25, .5, .75])
lowerq_inf = quartile_inf[0.25]
upperq_inf = quartile_inf[0.75]
iqr_inf = upperq_inf - lowerq_inf
upper_bound_inf = upperq_inf + (1.5*iqr_inf)
lower_bound_inf = lowerq_inf - (1.5*iqr_inf)

# print values and locate outliers for capomulin using calculations above
print(f'Infubinol IQR: {iqr_inf}')
print(f'Infubinol Lower Bound: {lower_bound_inf}')
print(f'Infubinol Upper Bound: {upper_bound_inf}')
print(f'Potential Outliers for Infubinol are values below {lower_bound_inf} or values above {upper_bound_inf}')
# Out:
# Infubinol IQR: 11.477135160000003
# Infubinol Lower Bound: 36.83290494999999
# Infubinol Upper Bound: 82.74144559000001
# Potential Outliers for Infubinol are values below 36.83290494999999 or values above 82.74144559000001

# %%
# Determine outliers using upper and lower bounds for Ceftamin
quartile_cef = treatments_df['Ceftamin'].quantile([.25, .5, .75])
lowerq_cef = quartile_cef[0.25]
upperq_cef = quartile_cef[0.75]
iqr_cef = upperq_cef - lowerq_cef
upper_bound_cef = upperq_cef + (1.5*iqr_cef)
lower_bound_cef = lowerq_cef - (1.5*iqr_cef)

# print values and locate outliers for capomulin using calculations above
print(f'Ceftamin IQR: {iqr_cef}')
print(f'Ceftamin Lower Bound: {lower_bound_cef}')
print(f'Ceftamin Upper Bound: {upper_bound_cef}')
print(f'Potential Outliers for Ceftamin are values below {lower_bound_cef} or values above {upper_bound_cef}')
# Out:
# Ceftamin IQR: 15.577752179999997
# Ceftamin Lower Bound: 25.355449580000002
# Ceftamin Upper Bound: 87.66645829999999
# Potential Outliers for Ceftamin are values below 25.355449580000002 or values above 87.66645829999999

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
boxplot_list = [treatments_df[treatments[0]],
               treatments_df[treatments[1]],
               treatments_df[treatments[2]],
               treatments_df[treatments[3]]]

# create box plot diagram and set labels for axes and title
fig1, ax = plt.subplots()
ax.set_title('Final Tumor volume by Drug Regimen') 
ax.set_xlabel('Drug Regimen') 
ax.set_ylabel('Tumor Vol (mm3)')

# used ax.boxplot function and ran boxplot_list to create the boxplot
ax.boxplot(boxplot_list)

# label x axies with drug names using list above 
plt.xticks([1,2,3,4], treatments) 

# show the plot
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# identify data associated with a specific mouse
mouse = new_clean_df.loc[new_clean_df['Mouse ID'] == 'x401']

# create line plot with time points and tumor volume
plt.plot(mouse['Timepoint'], mouse['Tumor Volume (mm3)'], marker = 's')

# create labels for axes and title
plt.xlabel('Time (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Capomulin Treatment for Mouse x401')

# show plot
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# find only the data for the tumors only on the capomulin regimen
capomulin_df = new_clean_df.loc[new_clean_df['Drug Regimen'] == "Capomulin", :]

# group the info above with the averages of the tumor volumes under this treatment
capomulin_avg = capomulin_df.groupby(['Mouse ID']).mean()

# create the scatter plot and label x, y axis and title
plt.scatter(capomulin_avg['Weight (g)'], capomulin_avg['Tumor Volume (mm3)'])
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Mouse Weight v. Average Tumor Volume')

# show the plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(capomulin_avg['Weight (g)'], capomulin_avg['Tumor Volume (mm3)'])
print(f'The correlation coefficient is {correlation[0]}.')
# Out:
# The correlation coefficient is 0.8419363424694717.

# %%
# creating scatter plot with liner regression model
# Print out the r-squared value along with the plot.
x_values = capomulin_avg['Weight (g)']
y_values = capomulin_avg['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (17,37), fontsize=15, color='red')
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Mouse Weight vs. Average Tumor Volume')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7088568047708717
